# %% [markdown]
# # Menginstal Liblary 🛠️

# %%
# !pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Mengimport Liblary 🗃️

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np
from google_play_scraper import  Sort, reviews

# %% [markdown]
# # Data Scrapping 📚

# %% [markdown]
# **Untuk Datasetnya, Mengambil semua ulasan dari aplikasi dengan ID com.shopee.id di Google Play Store.**

# %%
result, continuation_token = reviews(
    'com.shopee.id',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=50000,
    filter_score_with=None
)

# %%
shopee_df= pd.DataFrame(np.array(result),columns=['review'])
shopee_df = shopee_df.join(pd.DataFrame(shopee_df.pop('review').tolist()))

# %%
shopee_df.head()
# Out:
#                                reviewId         userName  \
# 0  cd46566c-34ad-4913-bb92-b120dcdb4ca2  Pengguna Google
# 1  409d7214-f8e2-4bf1-9206-06574f3cbd0f  Pengguna Google
# 2  7cb55bda-c206-4598-bad8-707b630f3e93  Pengguna Google
# 3  3adbc417-923a-470b-a9ff-b15bff6463b3  Pengguna Google
# 4  5738c89a-5dc0-40c2-a1d0-afb35c1c945a  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  jika status pesanan sudah "Dalam pengantaran k...      1            119
# 1  aplikasi cukup bagus, tapi kenapa tiap buka ap...      3             68
# ...

# %% [markdown]
# ## Jumlah Dataset yang Digunakan

# %%
print("Jumlah review yang diambil:", len(shopee_df.index))
# Out:
# Jumlah review yang diambil: 50000

# %% [markdown]
# ## Mengseleksi Dataset (Kolom) yang Relavan

# %%
shopee_df[['userName', 'score', 'at', 'content']].head()
# Out:
#           userName  score                  at  \
# 0  Pengguna Google      1 2025-04-04 08:27:55
# 1  Pengguna Google      3 2025-04-04 12:46:59
# 2  Pengguna Google      2 2025-04-04 10:45:25
# 3  Pengguna Google      1 2025-04-05 00:06:13
# 4  Pengguna Google      4 2025-04-04 07:50:20
#
#                                              content
# 0  jika status pesanan sudah "Dalam pengantaran k...
# 1  aplikasi cukup bagus, tapi kenapa tiap buka ap...
# 2  apps nya sebenarnya udah ok banget, cuman saya...
# 3  dulu lancar-lancar ajaCOD..tp COD skrg kok mal...
# 4  Tolong Shopee untuk default beranda jangan liv...

# %% [markdown]
# ## Mengurutkan Dataset (Tanggal/at) **untuk melihat sajah**

# %%
feature_df = shopee_df[['userName', 'score', 'at', 'content']]
feature_df = feature_df.sort_values(by='at', ascending=False)
feature_df.head()
# Out:
#               userName  score                  at  \
# 19001  Pengguna Google      5 2025-04-06 00:58:27
# 18261  Pengguna Google      5 2025-04-05 17:52:36
# 16728  Pengguna Google      5 2025-04-05 17:40:46
# 1800   Pengguna Google      5 2025-04-05 17:30:41
# 18327  Pengguna Google      5 2025-04-05 17:29:30
#
#                                                  content
# 19001  beli shopeefood dpt bug, makanan udh dicancel ...
# 18261     [mantapp] banyak diskon mulu penegiriman cepat
# 16728  Masih Berat geser ke bawah atas, mungkin terla...
# 1800   sudah nyaman shoping² di keranjang orens shope...
# 18327  sangat bagus mantap banyak diskon dan koin koi...

# %% [markdown]
# # Menyimpan Dataset Hasil Scraping 📦

# %%
feature_df.to_csv("shopee_reviews.csv", index = False)
