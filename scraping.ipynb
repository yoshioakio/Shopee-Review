# %% [markdown]
# # Menginstal Liblary 🛠️

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %% [markdown]
# # Mengimport Liblary 🗃️

# %%
from google_play_scraper import app
import pandas as pd
import numpy as np
from google_play_scraper import  Sort, reviews

# %% [markdown]
# # Data Scrapping 📚

# %% [markdown]
# **Untuk Datasetnya, Mengambil semua ulasan dari aplikasi dengan ID com.shopee.id di Google Play Store.**

# %%
result, continuation_token = reviews(
    'com.shopee.id',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=30000,
    filter_score_with=None
)

# %%
shopee_df= pd.DataFrame(np.array(result),columns=['review'])
shopee_df = shopee_df.join(pd.DataFrame(shopee_df.pop('review').tolist()))

# %%
shopee_df.head()
# Out:
#                                reviewId         userName  \
# 0  cd46566c-34ad-4913-bb92-b120dcdb4ca2  Pengguna Google
# 1  409d7214-f8e2-4bf1-9206-06574f3cbd0f  Pengguna Google
# 2  7cb55bda-c206-4598-bad8-707b630f3e93  Pengguna Google
# 3  5738c89a-5dc0-40c2-a1d0-afb35c1c945a  Pengguna Google
# 4  e2705c2c-b4ab-4dbc-af84-369510a3ebae  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  jika status pesanan sudah "Dalam pengantaran k...      1             11
# 1  aplikasi cukup bagus, tapi kenapa tiap buka ap...      3              4
# 2  apps nya sebenarnya udah ok banget, cuman saya...      2              7
# 3  Tolong Shopee untuk default beranda jangan liv...      4              5
# 4  Bug nya ngeselin banget, masa kga ada recent a...      4             47
#
#   reviewCreatedVersion                  at  \
# 0              3.47.39 2025-04-04 08:27:55
# 1              3.47.39 2025-04-04 12:46:59
# 2              3.47.39 2025-04-04 10:45:25
# 3              3.47.39 2025-04-04 07:50:20
# 4              3.47.39 2025-04-03 15:12:21
#
#                                         replyContent           repliedAt  \
# 0  Hai kak Komar Jaenudin, terima kasih ya untuk ... 2025-04-04 10:02:36
# 1  Hi Kak marso, maaf bgt ya buat kamu resah terk... 2025-04-04 07:15:37
# 2  Hai kak Mitha Rahmawati. Maaf terkait kendala ... 2025-04-04 11:27:57
# 3  Hi kak Tyo_ Yusuf41, maaf ya soal kendala apli... 2025-04-04 08:54:31
# 4  Hai kak Imelda Parhusip, mohon maaf ya atas ke... 2025-04-03 16:29:49
#
#   appVersion
# 0    3.47.39
# 1    3.47.39
# 2    3.47.39
# 3    3.47.39
# 4    3.47.39

# %% [markdown]
# ## Jumlah Dataset yang Digunakan

# %%
print("Jumlah review yang diambil:", len(shopee_df.index))
# Out:
# Jumlah review yang diambil: 30000

# %% [markdown]
# ## Mengseleksi Dataset (Kolom) yang Relavan

# %%
shopee_df[['userName', 'score', 'at', 'content']].head()
# Out:
#           userName  score                  at  \
# 0  Pengguna Google      1 2025-04-04 08:27:55
# 1  Pengguna Google      3 2025-04-04 12:46:59
# 2  Pengguna Google      2 2025-04-04 10:45:25
# 3  Pengguna Google      4 2025-04-04 07:50:20
# 4  Pengguna Google      4 2025-04-03 15:12:21
#
#                                              content
# 0  jika status pesanan sudah "Dalam pengantaran k...
# 1  aplikasi cukup bagus, tapi kenapa tiap buka ap...
# 2  apps nya sebenarnya udah ok banget, cuman saya...
# 3  Tolong Shopee untuk default beranda jangan liv...
# 4  Bug nya ngeselin banget, masa kga ada recent a...

# %% [markdown]
# ## Mengurutkan Dataset (Tanggal/at) **untuk melihat sajah**

# %%
feature_df = shopee_df[['userName', 'score', 'at', 'content']]
feature_df = feature_df.sort_values(by='at', ascending=False)
feature_df.head()
# Out:
#               userName  score                  at  \
# 19160  Pengguna Google      1 2025-04-05 00:30:39
# 13     Pengguna Google      3 2025-04-04 23:16:47
# 4976   Pengguna Google      1 2025-04-04 22:45:48
# 22624  Pengguna Google      5 2025-04-04 17:53:35
# 18829  Pengguna Google      5 2025-04-04 17:46:44
#
#                                                  content
# 19160  Pengiriman Sangat Lambat Anjirr 🤬😡 Muak Aku Nu...
# 13     kenapa ya ga bisa ganti nomor telp ;(, tolong ...
# 4976   Pengiriman ekspedisi JNT Express kenapa tiba t...
# 22624  bagus bagus tingkatkan lagi agar lebih bagus m...
# 18829  bagusss bangett tapi kalo bisa penjualny lebih...

# %% [markdown]
# # Menyimpan Dataset Hasil Scraping 📦

# %%
feature_df.to_csv("shopee_reviews.csv", index = False)
